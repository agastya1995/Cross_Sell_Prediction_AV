# %% [markdown]
# ### Use WOE Encoding to convert region and sales channels into integers ###
# **Notebook 3**
#
# This notebook will:
# 1. Convert sales channel and region codes to numerical features using WOE Encoder, and save the resulting dataset to a pickle file
# 2. Add interaction between certain other categories, intergrate it with the WOE Encoded data, and save the data to a pickle file.

# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('preprocessed_data_frame', 'rb') as f:
    df = pickle.load(f)

with open('target', 'rb') as f:
    target = pickle.load(f)

# %%
df.head(2)
# Out:
#   Gender  Age Region_Code  Previously_Insured Vehicle_Age Vehicle_Damage  \
# 0   Male   44          28                   0   > 2 Years            Yes
# 1   Male   76           3                   0    1-2 Year             No
#
#    Annual_Premium Policy_Sales_Channel  Vintage
# 0         40454.0                   26      217
# 1         33536.0                   26      183

# %%
df[['Region_Code', 'Policy_Sales_Channel']].nunique()
# Out:
# Region_Code              53
# Policy_Sales_Channel    155
# dtype: int64

# %%
target.head(2)
# Out:
# 0    1
# 1    0
# Name: Response, dtype: int64

# %%
# Trying WOE encoding
from category_encoders import WOEEncoder

# %%
woe = WOEEncoder(cols=['Region_Code', 'Policy_Sales_Channel'])
df = woe.fit_transform(df, target)
# Out:
# C:\Users\agast\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df
# Out:
#         Gender  Age  Region_Code  Previously_Insured Vehicle_Age  \
# 0         Male   44     0.499831                   0   > 2 Years
# 1         Male   76     0.047270                   0    1-2 Year
# 2         Male   47     0.499831                   0   > 2 Years
# 3         Male   21    -0.093676                   1    < 1 Year
# 4       Female   29    -0.006989                   1    < 1 Year
# ...        ...  ...          ...                 ...         ...
# 381104    Male   74    -0.578859                   1    1-2 Year
# 381105    Male   30    -0.482034                   1    < 1 Year
# 381106    Male   21    -0.560005                   1    < 1 Year
# 381107  Female   68    -0.340608                   0   > 2 Years
# 381108    Male   46     0.007998                   0    1-2 Year
#
#        Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0                 Yes         40454.0              0.578246      217
# 1                  No         33536.0              0.578246      183
# 2                 Yes         38294.0              0.578246       27
# 3                  No         28619.0             -1.555892      203
# 4                  No         27496.0             -1.555892       39
# ...               ...             ...                   ...      ...
# 381104             No         30170.0              0.578246       88
# 381105             No         40016.0             -1.555892      131
# 381106             No         35118.0             -1.832939      161
# 381107            Yes         44617.0              0.512838       74
# 381108             No         41777.0              0.578246      237
#
# [381109 rows x 9 columns]

# %%
# Convert the other categorical items to dummies
df = pd.get_dummies(df, drop_first=True)

# %%
df.columns
# Out:
# Index(['Age', 'Region_Code', 'Previously_Insured', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Gender_Male',
#        'Vehicle_Age_< 1 Year', 'Vehicle_Age_> 2 Years', 'Vehicle_Damage_Yes'],
#       dtype='object')

# %%
# Rename the columns which have a '<' or a '>' in it, otherwise it will not work with XGBoost
df = df.rename(columns={'Vehicle_Age_< 1 Year':'Vehicle_Age_Under_1_Year', 'Vehicle_Age_> 2 Years': 'Vehicle_Age_Over_2_Years'})

# %%
df
# Out:
#         Age  Region_Code  Previously_Insured  Annual_Premium  \
# 0        44     0.499831                   0         40454.0
# 1        76     0.047270                   0         33536.0
# 2        47     0.499831                   0         38294.0
# 3        21    -0.093676                   1         28619.0
# 4        29    -0.006989                   1         27496.0
# ...     ...          ...                 ...             ...
# 381104   74    -0.578859                   1         30170.0
# 381105   30    -0.482034                   1         40016.0
# 381106   21    -0.560005                   1         35118.0
# 381107   68    -0.340608                   0         44617.0
# 381108   46     0.007998                   0         41777.0
#
#         Policy_Sales_Channel  Vintage  Gender_Male  Vehicle_Age_Under_1_Year  \
# 0                   0.578246      217            1                         0
# 1                   0.578246      183            1                         0
# 2                   0.578246       27            1                         0
# 3                  -1.555892      203            1                         1
# 4                  -1.555892       39            0                         1
# ...                      ...      ...          ...                       ...
# 381104              0.578246       88            1                         0
# 381105             -1.555892      131            1                         1
# 381106             -1.832939      161            1                         1
# 381107              0.512838       74            0                         0
# 381108              0.578246      237            1                         0
#
#         Vehicle_Age_Over_2_Years  Vehicle_Damage_Yes
# 0                              1                   1
# 1                              0                   0
# 2                              1                   1
# 3                              0                   0
# 4                              0                   0
# ...                          ...                 ...
# 381104                         0                   0
# 381105                         0                   0
# 381106                         0                   0
# 381107                         1                   1
# 381108                         0                   0
#
# [381109 rows x 10 columns]

# %%
# Save to pickle
with open('WOE_Encoded_Data', 'wb') as f:
    pickle.dump(df, f)

# %%
df
# Out:
#         Age  Region_Code  Previously_Insured  Annual_Premium  \
# 0        44     0.499831                   0         40454.0
# 1        76     0.047270                   0         33536.0
# 2        47     0.499831                   0         38294.0
# 3        21    -0.093676                   1         28619.0
# 4        29    -0.006989                   1         27496.0
# ...     ...          ...                 ...             ...
# 381104   74    -0.578859                   1         30170.0
# 381105   30    -0.482034                   1         40016.0
# 381106   21    -0.560005                   1         35118.0
# 381107   68    -0.340608                   0         44617.0
# 381108   46     0.007998                   0         41777.0
#
#         Policy_Sales_Channel  Vintage  Gender_Male  Vehicle_Age_Under_1_Year  \
# 0                   0.578246      217            1                         0
# 1                   0.578246      183            1                         0
# 2                   0.578246       27            1                         0
# 3                  -1.555892      203            1                         1
# 4                  -1.555892       39            0                         1
# ...                      ...      ...          ...                       ...
# 381104              0.578246       88            1                         0
# 381105             -1.555892      131            1                         1
# 381106             -1.832939      161            1                         1
# 381107              0.512838       74            0                         0
# 381108              0.578246      237            1                         0
#
#         Vehicle_Age_Over_2_Years  Vehicle_Damage_Yes
# 0                              1                   1
# 1                              0                   0
# 2                              1                   1
# 3                              0                   0
# 4                              0                   0
# ...                          ...                 ...
# 381104                         0                   0
# 381105                         0                   0
# 381106                         0                   0
# 381107                         1                   1
# 381108                         0                   0
#
# [381109 rows x 10 columns]

# %%
df['Previously_Insured'] = df['Previously_Insured'].astype('uint8')

# %%
# Make interaction effects between previously insured, vehicle age and gender
categories_only = df.loc[:, df.columns[df.dtypes == 'uint8']]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
categories_only
# Out:
#         Previously_Insured  Gender_Male  Vehicle_Age_Under_1_Year  \
# 0                        0            1                         0
# 1                        0            1                         0
# 2                        0            1                         0
# 3                        1            1                         1
# 4                        1            0                         1
# ...                    ...          ...                       ...
# 381104                   1            1                         0
# 381105                   1            1                         1
# 381106                   1            1                         1
# 381107                   0            0                         0
# 381108                   0            1                         0
#
#         Vehicle_Age_Over_2_Years  Vehicle_Damage_Yes
# 0                              1                   1
# 1                              0                   0
# 2                              1                   1
# 3                              0                   0
# 4                              0                   0
# ...                          ...                 ...
# 381104                         0                   0
# 381105                         0                   0
# 381106                         0                   0
# 381107                         1                   1
# 381108                         0                   0
#
# [381109 rows x 5 columns]

# %% [markdown]
# Features to make:
# 1. Previously Insured * Gender
# 3. Previously Insured * Vehicle Damage
# 5. Vehicle Age * Vehicle Damage
# 6. Gender * Vehicle Damage

# %%
df['Gender_Male']*df['Vehicle_Damage_Yes']
# Out:
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 381104    0
# 381105    0
# 381106    0
# 381107    0
# 381108    0
# Length: 381109, dtype: uint8

# %%
df['Previously_Insured_Gender'] = df['Previously_Insured']*df['Gender_Male']
df['Previously_Insured_Vehicle_Damage'] = df['Previously_Insured']*df['Vehicle_Damage_Yes']
df['Vehicle_Age_Under_1_Vehicle_Damage'] = df['Vehicle_Age_Under_1_Year']*df['Vehicle_Damage_Yes']
df['Vehicle_Age_Over_2_Vehicle_Damage'] =df['Vehicle_Age_Over_2_Years']*df['Vehicle_Damage_Yes']
df['Gender_Vehicle_Damage'] = df['Gender_Male']*df['Vehicle_Damage_Yes']

# %%
df
# Out:
#         Age  Region_Code  Previously_Insured  Annual_Premium  \
# 0        44     0.499831                   0         40454.0
# 1        76     0.047270                   0         33536.0
# 2        47     0.499831                   0         38294.0
# 3        21    -0.093676                   1         28619.0
# 4        29    -0.006989                   1         27496.0
# ...     ...          ...                 ...             ...
# 381104   74    -0.578859                   1         30170.0
# 381105   30    -0.482034                   1         40016.0
# 381106   21    -0.560005                   1         35118.0
# 381107   68    -0.340608                   0         44617.0
# 381108   46     0.007998                   0         41777.0
#
#         Policy_Sales_Channel  Vintage  Gender_Male  Vehicle_Age_Under_1_Year  \
# 0                   0.578246      217            1                         0
# 1                   0.578246      183            1                         0
# 2                   0.578246       27            1                         0
# 3                  -1.555892      203            1                         1
# 4                  -1.555892       39            0                         1
# ...                      ...      ...          ...                       ...
# 381104              0.578246       88            1                         0
# 381105             -1.555892      131            1                         1
# 381106             -1.832939      161            1                         1
# 381107              0.512838       74            0                         0
# 381108              0.578246      237            1                         0
#
#         Vehicle_Age_Over_2_Years  Vehicle_Damage_Yes  \
# 0                              1                   1
# 1                              0                   0
# 2                              1                   1
# 3                              0                   0
# 4                              0                   0
# ...                          ...                 ...
# 381104                         0                   0
# 381105                         0                   0
# 381106                         0                   0
# 381107                         1                   1
# 381108                         0                   0
#
#         Previously_Insured_Gender  Previously_Insured_Vehicle_Damage  \
# 0                               0                                  0
# 1                               0                                  0
# 2                               0                                  0
# 3                               1                                  0
# 4                               0                                  0
# ...                           ...                                ...
# 381104                          1                                  0
# 381105                          1                                  0
# 381106                          1                                  0
# 381107                          0                                  0
# 381108                          0                                  0
#
#         Vehicle_Age_Under_1_Vehicle_Damage  Vehicle_Age_Over_2_Vehicle_Damage  \
# 0                                        0                                  1
# 1                                        0                                  0
# 2                                        0                                  1
# 3                                        0                                  0
# 4                                        0                                  0
# ...                                    ...                                ...
# 381104                                   0                                  0
# 381105                                   0                                  0
# 381106                                   0                                  0
# 381107                                   0                                  1
# 381108                                   0                                  0
#
#         Gender_Vehicle_Damage
# 0                           1
# 1                           0
# 2                           1
# 3                           0
# 4                           0
# ...                       ...
# 381104                      0
# 381105                      0
# 381106                      0
# 381107                      0
# 381108                      0
#
# [381109 rows x 15 columns]

# %%
with open ('WOE_Encoded_with_Interaction', 'wb') as f:
    pickle.dump(df, f)
